# %%
## Simple code to anonymize based on liu terzi's k-anonymity graphs
#
### Steps are as follows:
## (a) Take in graph data; 
## (b) prepare the 'degree' vector 
## (c) Generate a d^ vector having min L1|d^ - d| - (Page 98 algorithm)
## (d) Constructgraph algorithm
## (e) Probing scheme 
## (F) Greedy_swap instead of dynamic programming
## (g) Priority algorithm
## 

""" PSeudo code for the 

"""

__author__ = 'karthik'

a = 'Hello world'
print a
# Out:
# Hello world
# is it still live

# %%
import networkx as nx
import pylab as plt 
g = nx.Graph()
lollipop=nx.lollipop_graph(10,20) 
nx.draw_random(lollipop)
plt.savefig('sample_graph.png')

# %%
f = open('sample_dataset.txt','w')
for item in lollipop:
    f.write(','.join(map(str,item)))
    f.write('\n')
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-7233442da736> in <module>()
#       1 f = open('sample_dataset.txt','w')
#       2 for item in lollipop:
# ----> 3     f.write(','.join(map(str,item)))
#       4     f.write('\n')
#       5 f.close()
#
# TypeError: argument 2 to map() must support iteration

# %%
import pandas as pd
#df = pd.DataFrame(lollipop) 
#df. lollipop
savetxt('sample_dataset.csv', lollipop, delimiter=',', fmt='%f')

# %%
print lollipop
# Out:
# lollipop_graph(10,20)

# %%
nx.write_edgelist(lollipop,'sample_dataset_edges.csv',comments='#',
                  delimiter=',',data=True,encoding='utf-8')

# %%
import snap
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-74d286b22ce6> in <module>()
# ----> 1 import snap
#
# ImportError: No module named snap

# %%
print "Hi"
# Out:
# Hi

# %%
fb_107=nx.Graph()

fb_107 = nx.read_edgelist('107.edges',comments='#',
                  delimiter=' ',data=True,encoding='utf-8')
print fb_107
nx.draw_random(fb_107)

# %%
## USe d3 : http://bl.ocks.org/mbostock/4062045 &  networkx: json : http://networkx.github.io/documentation/latest/examples/javascript/force.html 
## to convert to d3 visualization!
